# %%
# to enter and sum a number  
a = int(input("enter first number"))
b = int(input("enter second number"))
c = a + b
print("sum of the numbers is ",c)
# Out:
# enter first number 5
# enter second number 5
# sum of the numbers is  10

# %%
# to find the area of a rectangle
print("to find the sum of a rectangle enter length and breath :")
a=int(input("length="))
b=int(input("breath="))
area = 2*(a+b)

print("area of the rectangle is = ",area)
# Out:
# to find the sum of a rectangle enter length and breath :
# length= 4
# breath= 5
# area of the rectangle is =  18

# %%
#check datatype of input
a = int(input("enter a number"))

print(type(a))
# Out:
# enter a number 55
# <class 'int'>

# %%
# to calculate simple interest 
print("Enter principal Ammount , Interst , Time period in years respectively ")
p=float(input())
i=float(input())
t=float(input())

si=(p*i*t)/100
print("Simple Interest is = ",si)
# Out:
# Enter principal Ammount , Interst , Time period in years respectively
#  10000
#  10
#  10
# Simple Interest is =  10000.0

# %%
#to calculate the area and volume to a cube 
print("Enter the side of the cube in cm")
s=float(input())
ar=6*(s**2)
vol=s**3

print("Area of the cube is",ar , " Volume of the cube is", vol)
# Out:
# Enter the side of the cube in cm
#  5
# Area of the cube is 150.0  Volume of the cube is 125.0

# %%
#to convert  f to c 
print("enter the temperature in f")
f = int(input())
c=9/5*(f-32)

print("The temperature in c is =",c)
# Out:
# enter the temperature in f
#  55
# The temperature in c is = 41.4
