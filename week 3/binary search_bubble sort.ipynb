# %% [raw]
# WAP to implement Binary Search. (Sorted List)
# WAP to implement Bubble Sort. (Unsorted List)
# WAP to implement Selection Sort. (Unsorted List)
# WAP to implement Merge sort(DNFA). (Unsorted List)

# %%
#Binary Search. (Sorted List):
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
key = int(input("Enter element to search: "))
low = 0
high = n - 1
found = False
while low <= high:
    mid = (low + high) // 2
    if arr[mid] == key:
        print("Element found at index", mid)
        found = True
        break
    elif arr[mid] < key:
        low = mid + 1
    else:
        high = mid - 1
if not found:
    print("Element not found")
# Out:
# Enter number of elements:  3
# Enter element 1:  1
# Enter element 2:  2
# Enter element 3:  3
# Enter element to search:  2
# Element found at index 1

# %%
#Bubble Sort. (Unsorted List)
n = int(input("Enter number of elements: "))
arr = []
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}: ")))
print("Unsorted List:", arr)
for i in range(n - 1):
    for j in range(n - 1 - i):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]
print("Sorted List:", arr)
# Out:
# Enter number of elements:  5
# Enter element 1:  55
# Enter element 2:  44
# Enter element 3:  88
# Enter element 4:  62
# Enter element 5:  44
# Unsorted List: [55, 44, 88, 62, 44]
# Sorted List: [44, 44, 55, 62, 88]

# %%
def mergeSort(arr1,arr2):
    i,j = 0,0
    arr = []
    while (i<len(arr1) j<len(arr2)):
        if arr1[i]==arr2[j]:
            arr.append(arr1[i])
            arr.append(arr2[j])
            j+=1
            i+=1
        elif arr1[i]>arr2[j]:
            arr.append(arr2[j])
            j+=1
        elif arr2[j]>arr1[i]:
            arr.append(arr1[i])
            i+=1
