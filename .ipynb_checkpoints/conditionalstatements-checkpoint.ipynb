# %%
#to check if elegibal to vote
#check if even or odd
#check multiple of 5 or not
#if no. is divisible by 35 or not
#print last digit of no.

# %%
#to check if elegibal to vote
age=int(input("enter your age"))
if age >=18:
    print("eligibleto vote")
else:
    print("not eligible to vote")
# Out:
# enter your age 55
# eligibleto vote

# %%
#check even or odd
num=int(input("enter a number"))
if num%2==0:
    print("even number")
else:
    print("odd number ")
# Out:
# enter a number 5
# odd number

# %%
#check multiple of 5 or not
num=int(input("enter a number"))
if num%5==0:
    print(num,"multiple of 5 ")
else:
    print(num," is not a multiple of 5 ")
# Out:
# enter a number 6
# 6  is notmultiple of 5

# %%
#if no. is divisible by 35 or not
num=int(input("enter a number"))
if num%35==0:
    print(num,"divisible by 35 ")
else:
    print(num," is not a divisible by 35 ")
# Out:
# enter a number 5
# 5  is not a divisible by 35

# %%
#print last digit of no.
num=int(input("enter a number"))
print(num%10,"is the last digit of the number ")
# Out:
# enter a number 5
# 5 is the last digit of the number
