# %% [raw]
#                                                          linked list
#
# - LL is a collection of nodes
# - Everynode has 2 things :
#    - value
#    - refrence to next node
# - hence connections are maded through refrence
# - head stores the refrence to first node
# - tail stores the refrence to the last element
