# %% [raw]
#                                                        Time and Space Complexity
#
#
# TIME CPMPLEXITY
#
# - time complexity is a function which tells us the relations ship of how algorithm behaves as the input size increases .
#
# What do we consider about time complexity :
#  - it gives answer for worst case sinario .
#  - always look coplexity for larger data or infinite data.
#  - actual time for smaller may or maynot have have higher complexities but when the size of algo is increasing is that is what we need to consider .
#  - we dont consider constant values .
#  - always ignore less dominating term .
#  - O(1) < O(log n) < O(n) < O(n log n) < O(n^2) < O(n^3) < O(2^n).
#
# Big O notation :
# - this is upper bound/ worst case / max time taken .
# math exp :
#
# lim              f(n)        < infi
# n --> infi       g(n)
#
#
# Omega notation  :
# - lower bound / mini time taken / best case sinario
# math exp :
#
# lim              f(n)        >0
# n --> infi       g(n)
#
#
#
# Theta notation :
# - when upper and lower bound are same .
#
#
#
#
#
# time complexity :
#
# ques                             tc           sc
#
# swap 2 no.                       o(1)        o(1)
# add no. upto n                   o(n)        o(n)
# sum of two matrix                o(n^2)      o(n^2)
# mul of two matrix                o(n^3)      o(n^2)
# for (i=0;i>n;i++)                0(n)        o(n)
# for (i=n;i>0;i--)                0(n)        o(n)
# for (i=0;i>0;i+=2)               0(n)        o(n)
# for (i=0;i>0;i*=2)               0(logb2 n)  o(n)
# for (i=0;i>0;i/=2)               0(logb2 n)  o(n)
# two different loops              0(n)        o(n)
# bubble sort                      o(n^2)      o(n)
# selection sort                   o(n^2)      o(n)
# merge sort                       o(nlog n)   0(n)
# binary search                    0(logb2 n)  o(n)
