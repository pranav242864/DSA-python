# %% [markdown]
# property of stack :
# Last In First Out

# %% [raw]
# pop -  delete the top or last element
# push add a new element to the last
# top - get the last element
# size - total no. of elements
# isempty - to check if stack has 0 elements or not

# %%
stack = []
stack.append(10)
stack.append(20)
stack.append(30)
print(stack)
# Out:
# [10, 20, 30]

# %%
# how to delete top ele
stack.pop()
# Out:
# 30

# %%
stack
# Out:
# [10, 20]

# %%
# how to add a item at top
stack.append(40)
stack
# Out:
# [10, 20, 40]

# %%
# how to check top element
stack[-1]
# Out:
# 40

# %%
3 lenth of stack
len(stack) == 0
# Out:
# False

# %%
# total elements of stack 
len(stack)
# Out:
# 3

# %%
# in built stack using queue library 
import queue
s = queue.LifoQueue()
s.put(1)
s.put(5)
s.put(15)

while not s.empty():
    print(s.get())
# Out:
# 15
# 5
# 1

# %%
#INBUILT QUEUE 
import queue
s = queue.Queue()
s.put(1)
s.put(5)
s.put(15)

while not s.empty():
    print(s.get())
# Out:
# 1
# 5
# 15

# %%
def isBalanced(s):
    if not s:
        return ""
    stack = []
    for char in s:
        if char in '{[(':
            stack.append(char)
        elif char == ')':
            if (not stack or stack[-1] == ')'):
                return False
            stack.pop()
        elif char == ']':
            if (not stack or stack[-1] == ']'):
                return False
            stack.pop()
        elif char == '}':
            if (not stack or stack[-1] == '}'):
                return False
            stack.pop()
    if not stack:
        return True
    return False


s = input()
if isBalanced(s):
    print("True")
else:
    print ("False")
# Out:
#  ()
# True
